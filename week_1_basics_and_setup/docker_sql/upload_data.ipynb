# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.0.2'

# %%
df = pd.read_parquet('yellow_tripdata_2021-01.parquet')

# %%
df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2021-01-01 00:30:10   2021-01-01 00:36:12              1.0
# 1               1  2021-01-01 00:51:20   2021-01-01 00:52:19              1.0
# 2               1  2021-01-01 00:43:30   2021-01-01 01:11:06              1.0
# 3               1  2021-01-01 00:15:48   2021-01-01 00:31:01              0.0
# 4               2  2021-01-01 00:31:49   2021-01-01 00:48:21              1.0
# ...           ...                  ...                   ...              ...
# 1369764         2  2021-01-31 23:03:00   2021-01-31 23:33:00              NaN
# 1369765         2  2021-01-31 23:29:00   2021-01-31 23:51:00              NaN
# 1369766         2  2021-01-31 23:25:00   2021-01-31 23:38:00              NaN
# 1369767         6  2021-01-31 23:01:06   2021-02-01 00:02:03              NaN
# 1369768         2  2021-01-31 23:08:29   2021-01-31 23:31:22              NaN
#
# ...

# %%
from sqlalchemy import create_engine

# %%
# 'postgresql://username:password@localhost:5432/mydatabase'
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
engine.connect()

# %%
# Create schema DDL statement
print(pd.io.sql.get_schema(df, name='yellow_tripdata', con=engine))
# Out:
# CREATE TABLE yellow_tripdata (
# 	"VendorID" BIGINT,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count FLOAT(53),
# 	trip_distance FLOAT(53),
# 	"RatecodeID" FLOAT(53),
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53),
# 	airport_fee FLOAT(53)
# )

# %%
# Write to csv
df.to_csv('C:/Users/mattc/OneDrive/Documents/Data/data-engineering-zoomcamp/week_1_basics_and_setup/docker_sql/yellow_tripdata_2021-01.csv', index=False)

# %%
# Then read back that csv as we want to upload it to postgres in chunks so a good way is via an iterator with chunksize
df_iter = pd.read_csv('yellow_tripdata_2021-01.csv', iterator=True, chunksize=100_000)

# %%
df = next(df_iter)

# %%
df
# Out:
#        VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             1  2021-01-01 00:30:10   2021-01-01 00:36:12              1.0
# 1             1  2021-01-01 00:51:20   2021-01-01 00:52:19              1.0
# 2             1  2021-01-01 00:43:30   2021-01-01 01:11:06              1.0
# 3             1  2021-01-01 00:15:48   2021-01-01 00:31:01              0.0
# 4             2  2021-01-01 00:31:49   2021-01-01 00:48:21              1.0
# ...         ...                  ...                   ...              ...
# 99995         1  2021-01-04 14:04:31   2021-01-04 14:08:52              3.0
# 99996         1  2021-01-04 14:18:46   2021-01-04 14:35:45              2.0
# 99997         1  2021-01-04 14:42:41   2021-01-04 14:59:22              2.0
# 99998         2  2021-01-04 14:39:02   2021-01-04 15:09:37              2.0
# 99999         2  2021-01-04 14:49:36   2021-01-04 14:54:44              5.0
#
# ...

# %%
# Write a table to our postgres table in our container (using engine which defines the user/pass/port/etc.)
# If a table already exists then replace it with the data in df.head(0)
df.head(0).to_sql(name='yellow_tripdata', con=engine, if_exists='replace')
# Out:
# 0

# %%
df.to_sql(name='yellow_tripdata', con=engine, if_exists='append')
# Out:
# 1000

# %%
import time

# %%
while True:
    start_time = time.time()

    df = next(df_iter)
    df.to_sql(name='yellow_tripdata', con=engine, if_exists='append')
    
    end_time = time.time()
    
    print(f'Data added to postgres. Time taken {end_time - start_time:.3f}s')
# Out:
# Data added to postgres. Time taken 10.000s
# Data added to postgres. Time taken 8.496s
# Data added to postgres. Time taken 12.322s
# Data added to postgres. Time taken 10.221s
# Data added to postgres. Time taken 7.843s
# Data added to postgres. Time taken 8.384s
# Data added to postgres. Time taken 8.858s
# Data added to postgres. Time taken 11.841s
# Data added to postgres. Time taken 8.637s
# Data added to postgres. Time taken 9.433s
# Data added to postgres. Time taken 8.570s
# C:\Users\mattc\AppData\Local\Temp\ipykernel_21672\947986654.py:4: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = next(df_iter)
# Data added to postgres. Time taken 8.299s
# Data added to postgres. Time taken 7.326s
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[23], line 4
#       1 while True:
# ...
